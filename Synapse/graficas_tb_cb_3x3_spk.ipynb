# %%
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
import sys


BSIZE_SP = 512 # Max size of a line of data; we don't want to read the
               # whole file to find a line, in case file does not have
               # expected structure.

MDATA_LIST = [b'title', b'date', b'plotname', b'flags', b'no. variables',
              b'no. points', b'dimensions', b'command', b'option']

def rawread(fname: str):
    """Read ngspice binary raw files. Return tuple of the data, and the
    plot metadata. The dtype of the data contains field names. This is
    not very robust yet, and only supports ngspice.
    
    >>> darr, mdata = rawread('test.py')
    >>> darr.dtype.names
    >>> plot(np.real(darr['frequency']), np.abs(darr['v(out)']))
    """
    # Example header of raw file
    # Title: rc band pass example circuit
    # Date: Sun Feb 21 11:29:14  2016
    # Plotname: AC Analysis
    # Flags: complex
    # No. Variables: 3
    # No. Points: 41
    # Variables:
    #         0       frequency       frequency       grid=3
    #         1       v(out)  voltage
    #         2       v(in)   voltage
    # Binary:
    fp = open(fname, 'rb')
    arrs = []
    plots = []
    plot = {}
    while (True):
        try:
            # mdata = fp.readline(BSIZE_SP).split(b':', maxsplit=1)
            mdata = fp.readline().split(b':', maxsplit=1)
        except:
            raise
        if len(mdata) == 2:
            if mdata[0].lower() in MDATA_LIST:
                plot[mdata[0].lower()] = mdata[1].strip()
            if mdata[0].lower() == b'variables':
                nvars = int(plot[b'no. variables'])
                npoints = int(plot[b'no. points'])
                plot['varnames'] = []
                plot['varunits'] = []
                for varn in range(nvars):
                    # varspec = (fp.readline(BSIZE_SP).strip().decode('ascii').split())
                    varspec = (fp.readline().strip().decode('ascii').split())
                    assert(varn == int(varspec[0]))
                    plot['varnames'].append(varspec[1])
                    plot['varunits'].append(varspec[2])
            if mdata[0].lower() == b'binary':
                rowdtype = np.dtype({'names': plot['varnames'],
                                     'formats': [np.complex_ if b'complex'
                                                 in plot[b'flags']
                                                 else np.float64]*nvars})
                # We should have all the metadata by now
                arrs.append(np.fromfile(fp, dtype=rowdtype, count=npoints))
                plots.append(plot)
                plot = {} # reset the plot dict
                fp.readline() # Read to the end of line
        else:
            break
    return (arrs[0], plots)

data, dicc = rawread("tb_cb_3x3_spk.raw")

# %%
dicc
# Out:
# [{b'title': b'** sch_path: /foss/designs/snn-buck-boost/synapse/tb_cb_3x3_spk.sch',
#   b'date': b'Tue Mar 17 16:21:42  2026',
#   b'command': b'ngspice-45.2, Build Sun Dec 21 19:31:43 UTC 2025',
#   b'plotname': b'Transient Analysis',
#   b'flags': b'real',
#   b'no. variables': b'130',
#   b'no. points': b'25685',
#   'varnames': ['time',
#    'v(m.x1.xm1.msky130_fd_pr__pfet_01v8#body)',
#    'v(m.x1.xm1.msky130_fd_pr__pfet_01v8#dbody)',
#    'v(m.x1.xm1.msky130_fd_pr__pfet_01v8#sbody)',
#    'v(m.x1.xm2.msky130_fd_pr__pfet_01v8#body)',
#    'v(m.x1.xm2.msky130_fd_pr__pfet_01v8#dbody)',
#    'v(m.x1.xm2.msky130_fd_pr__pfet_01v8#sbody)',
#    'v(m.x1.xm3.msky130_fd_pr__pfet_01v8#body)',
#    'v(m.x1.xm3.msky130_fd_pr__pfet_01v8#dbody)',
#    'v(m.x1.xm3.msky130_fd_pr__pfet_01v8#sbody)',
#    'v(m.x1.xm4.msky130_fd_pr__pfet_01v8#body)',
#    'v(m.x1.xm4.msky130_fd_pr__pfet_01v8#dbody)',
#    'v(m.x1.xm4.msky130_fd_pr__pfet_01v8#sbody)',
#    'v(m.x1.xm5.msky130_fd_pr__pfet_01v8#body)',
#    'v(m.x1.xm5.msky130_fd_pr__pfet_01v8#dbody)',
#    'v(m.x1.xm5.msky130_fd_pr__pfet_01v8#sbody)',
#    'v(m.x1.xm6.msky130_fd_pr__pfet_01v8#body)',
#    'v(m.x1.xm6.msky130_fd_pr__pfet_01v8#dbody)',
#    'v(m.x1.xm6.msky130_fd_pr__pfet_01v8#sbody)',
#    'v(m.x1.xm7.msky130_fd_pr__nfet_01v8#body)',
#    'v(m.x1.xm7.msky130_fd_pr__nfet_01v8#dbody)',
#    'v(m.x1.xm7.msky130_fd_pr__nfet_01v8#sbody)',
#    'v(m.x1.xm8.msky130_fd_pr__nfet_01v8#body)',
#    'v(m.x1.xm8.msky130_fd_pr__nfet_01v8#dbody)',
#    'v(m.x1.xm8.msky130_fd_pr__nfet_01v8#sbody)',
#    'v(m.x1.xm9.msky130_fd_pr__nfet_01v8#body)',
#    'v(m.x1.xm9.msky130_fd_pr__nfet_01v8#dbody)',
#    'v(m.x1.xm9.msky130_fd_pr__nfet_01v8#sbody)',
#    'v(m.x1.xm10.msky130_fd_pr__nfet_01v8#body)',
#    'v(m.x1.xm10.msky130_fd_pr__nfet_01v8#dbody)',
#    'v(m.x1.xm10.msky130_fd_pr__nfet_01v8#sbody)',
#    'v(m.x1.xm11.msky130_fd_pr__nfet_01v8#body)',
#    'v(m.x1.xm11.msky130_fd_pr__nfet_01v8#dbody)',
#    'v(m.x1.xm11.msky130_fd_pr__nfet_01v8#sbody)',
#    'v(m.x1.xm12.msky130_fd_pr__nfet_01v8#body)',
#    'v(m.x1.xm12.msky130_fd_pr__nfet_01v8#dbody)',
#    'v(m.x1.xm12.msky130_fd_pr__nfet_01v8#sbody)',
#    'v(m.x1.xm13.msky130_fd_pr__pfet_01v8#body)',
#    'v(m.x1.xm13.msky130_fd_pr__pfet_01v8#dbody)',
#    'v(m.x1.xm13.msky130_fd_pr__pfet_01v8#sbody)',
#    'v(m.x1.xm14.msky130_fd_pr__nfet_01v8#body)',
#    'v(m.x1.xm14.msky130_fd_pr__nfet_01v8#dbody)',
#    'v(m.x1.xm14.msky130_fd_pr__nfet_01v8#sbody)',
#    'v(m.x1.xm15.msky130_fd_pr__pfet_01v8#body)',
#    'v(m.x1.xm15.msky130_fd_pr__pfet_01v8#dbody)',
#    'v(m.x1.xm15.msky130_fd_pr__pfet_01v8#sbody)',
#    'v(m.x1.xm16.msky130_fd_pr__nfet_01v8#body)',
#    'v(m.x1.xm16.msky130_fd_pr__nfet_01v8#dbody)',
#    'v(m.x1.xm16.msky130_fd_pr__nfet_01v8#sbody)',
#    'v(m.x1.xm17.msky130_fd_pr__pfet_01v8#body)',
#    'v(m.x1.xm17.msky130_fd_pr__pfet_01v8#dbody)',
#    'v(m.x1.xm17.msky130_fd_pr__pfet_01v8#sbody)',
#    'v(m.x1.xm18.msky130_fd_pr__nfet_01v8#body)',
#    'v(m.x1.xm18.msky130_fd_pr__nfet_01v8#dbody)',
#    'v(m.x1.xm18.msky130_fd_pr__nfet_01v8#sbody)',
#    'v(m.x1.xm19.msky130_fd_pr__pfet_01v8#body)',
#    'v(m.x1.xm19.msky130_fd_pr__pfet_01v8#dbody)',
#    'v(m.x1.xm19.msky130_fd_pr__pfet_01v8#sbody)',
#    'v(m.x1.xm20.msky130_fd_pr__nfet_01v8#body)',
#    'v(m.x1.xm20.msky130_fd_pr__nfet_01v8#dbody)',
#    'v(m.x1.xm20.msky130_fd_pr__nfet_01v8#sbody)',
#    'v(m.x1.xm21.msky130_fd_pr__pfet_01v8#body)',
#    'v(m.x1.xm21.msky130_fd_pr__pfet_01v8#dbody)',
#    'v(m.x1.xm21.msky130_fd_pr__pfet_01v8#sbody)',
#    'v(m.x1.xm22.msky130_fd_pr__nfet_01v8#body)',
#    'v(m.x1.xm22.msky130_fd_pr__nfet_01v8#dbody)',
#    'v(m.x1.xm22.msky130_fd_pr__nfet_01v8#sbody)',
#    'v(m.x1.xm23.msky130_fd_pr__pfet_01v8#body)',
#    'v(m.x1.xm23.msky130_fd_pr__pfet_01v8#dbody)',
#    'v(m.x1.xm23.msky130_fd_pr__pfet_01v8#sbody)',
#    'v(m.x1.xm24.msky130_fd_pr__nfet_01v8#body)',
#    'v(m.x1.xm24.msky130_fd_pr__nfet_01v8#dbody)',
#    'v(m.x1.xm24.msky130_fd_pr__nfet_01v8#sbody)',
#    'v(m.x1.xm25.msky130_fd_pr__pfet_01v8#body)',
#    'v(m.x1.xm25.msky130_fd_pr__pfet_01v8#dbody)',
#    'v(m.x1.xm25.msky130_fd_pr__pfet_01v8#sbody)',
#    'v(n.x1.xr1.n1#ngap)',
#    'v(n.x1.xr2.n1#ngap)',
#    'v(n.x1.xr3.n1#ngap)',
#    'v(n.x1.xr4.n1#ngap)',
#    'v(n.x1.xr5.n1#ngap)',
#    'v(n.x1.xr6.n1#ngap)',
#    'v(n.x1.xr7.n1#ngap)',
#    'v(n.x1.xr8.n1#ngap)',
#    'v(n.x1.xr9.n1#ngap)',
#    'v(n11)',
#    'v(n12)',
#    'v(n13)',
#    'v(n21)',
#    'v(n22)',
#    'v(n23)',
#    'i(v.x1.vam11)',
#    'i(v.x1.vam12)',
#    'i(v.x1.vam13)',
#    'i(v.x1.vam21)',
#    'i(v.x1.vam22)',
#    'i(v.x1.vam23)',
#    'i(v.x1.vam31)',
#    'i(v.x1.vam32)',
#    'i(v.x1.vam33)',
#    'i(v1)',
#    'i(v2)',
#    'i(v3)',
#    'i(v4)',
#    'i(v5)',
#    'i(v6)',
#    'i(v7)',
#    'v(vdd)',
#    'v(x1.be1)',
#    'v(x1.be2)',
#    'v(x1.be3)',
#    'v(x1.net1)',
#    'v(x1.net2)',
#    'v(x1.net3)',
#    'v(x1.net4)',
#    'v(x1.net5)',
#    'v(x1.net6)',
#    'v(x1.net7)',
#    'v(x1.net8)',
#    'v(x1.net9)',
#    'v(x1.nv1post)',
#    'v(x1.nv1pre)',
#    'v(x1.nv2post)',
#    'v(x1.nv2pre)',
#    'v(x1.nv3post)',
#    'v(x1.nv3pre)',
#    'v(x1.p)',
#    'v(x1.te1)',
#    'v(x1.te2)',
#    'v(x1.te3)'],
#   'varunits': ['time',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage']}]

# %%
fig, axes = plt.subplots(3, 3, figsize=(25,5))

# Loop through each subplot
for i in range(3):
    for j in range(3):
        Imem = data[f'i(v.x1.vam{i+1}{j+1})']
        vte = data[f'v(x1.te{i+1})']
        vbe = data[f'v(x1.be{j+1})']
        mem = (vte - vbe) 
        axes[i, j].plot(data["time"], mem, label = f"i{i+1}{j+1}")
        axes[i,j].set_ylim(-3.5e6, 3.5e6)

# Adjust spacing
plt.tight_layout()

# Show the figure
plt.show()

# %%
fig, axes = plt.subplots(3, 3, figsize=(10,10))

# Loop through each subplot
for i in range(3):
    for j in range(3):
        axes[i, j].plot(data["time"], data[f'i(v.x1.vam{i+1}{j+1})'], label = f"i{i+1}{j+1}")
        # axes[i, j].set_title(f"Plot {i*3 + j + 1}")

# Adjust spacing
plt.tight_layout()

# Show the figure
plt.show()

# %%
fig, axes = plt.subplots(9, 1, figsize=(10,20))
for i in range(9):
    axes[i].plot(data["time"], data[f'v(n.x1.xr{i+1}.n1#ngap)'], label = f"ngap{i+1}")
